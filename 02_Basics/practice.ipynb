// %%
let array = [1,2,3]

array.push(100)
array.push(200)


console.log(array)
// Out:
// [ 1, 2, 3, 100, 200 ]

// %%
const array1 = [10,20,30,40]

array1.pop()

console.log(array1)
// Out:
// [ 10, 20, 30 ]

// %%
let result = []

result.push(10)
result.push(20)
result.push(30)

console.log(result)

result.pop()

console.log(result)
// Out:
// [ 10, 20, 30 ]
// [ 10, 20 ]

// %%
const array2 = ["b","c","d"]

array2.unshift("start")

console.log(array2)
// Out:
// [ 'start', 'b', 'c', 'd' ]

// %%
const array3 = [100,200,300]

array3.shift()

console.log(array3)
// Out:
// [ 200, 300 ]

// %%
array4 = []

array4.push("A")
array4.push("B")
array4.push("C")

array4.shift()

console.log(array4)
// Out:
// [ 'B', 'C' ]

// %%
const fruits = ["banana","apple","mango"]


fruits.includes("apple")
// Out:
// true

// %%
let numbers = [10,20,30,40,50]

// %%
numbers.indexOf(40)
// Out:
// 3

// %%
let target = 65

let idx = numbers.indexOf(target)

if (idx == -1){
    console.log("Not Found")
}

else{
    console.log("Found at index:", index);
}
// Out:
// Not Found

// %%
let arr = ["JS","Python","Java"]

string = arr.join()

console.log(string)
// Out:
// JS,Python,Java

// %%
let words = ["learn","javascript","today"]

string_words = words.join("-")

console.log(string_words)
// Out:
// learn-javascript-today

// %%
let array5 = [1,2,3,4,5,6]

array5.slice(3)
// Out:
// [ 4, 5, 6 ]

// %%
array5.slice(0,3)
// Out:
// [ 1, 2, 3 ]

// %%
array5.slice(-2)
// Out:
// [ 5, 6 ]

// %%
let array6 = [10,20,30,40,50,60]

array6.slice(2,4)
// Out:
// [ 30, 40 ]

// %%
let array7 = [10,20,30,40,50,60]

array7.slice()
// Out:
// [ 10, 20, 30, 40, 50, 60 ]

// %%
let arra8 = [10,20,30,40,50]

arra8.splice(1,3)
// Out:
// [ 20, 30, 40 ]

// %%
console.log(arra8)
// Out:
// [ 10, 50 ]

// %%
const fruits = ["Apple", "Banana", "Cherry", "Date", "Elderberry"]; // Original array

// Using slice
const slicedFruits = fruits.slice(1, 4); // Copies elements from index 1 to 3 (index 4 excluded)
console.log("Sliced:", slicedFruits); // Logs: ["Banana", "Cherry", "Date"]
console.log("Original after slice:", fruits); // Original array remains unchanged

// Using splice
const splicedFruits = fruits.splice(1, 3); // Removes 3 elements starting from index 1
console.log("Spliced:", splicedFruits); // Logs: ["Banana", "Cherry", "Date"]
console.log("Original after splice:", fruits); // Modified array: ["Apple", "Elderberry"]
// Out:
// Sliced: [ 'Banana', 'Cherry', 'Date' ]
// Original after slice: [ 'Apple', 'Banana', 'Cherry', 'Date', 'Elderberry' ]
// Spliced: [ 'Banana', 'Cherry', 'Date' ]
// Original after splice: [ 'Apple', 'Elderberry' ]

// %%
let electronics = ["laptop","mobile phone","hardrive", "mouse","pendrive","keyboard"]

let slicedelectronics = electronics.slice(1,3)
console.log("Sliced:", slicedGadget); 
console.log("Original after slice:", gadget);
// Out:
// Sliced: [ 'mobile phone', 'hardrive' ]
// Original after slice: [ 'laptop' ]

// %%
let splicedelectronic = electronics.splice(1,3)
console.log("Spliced:", splicedelectronic); 
console.log("Original after splice:", gadget);
// Out:
// Spliced: []
// Original after splice: [ 'laptop' ]

// %%
let array9 = [10,20,30,40,50]

let splicedarray9 = array9.splice(1,3)

console.log("Spliced:",splicedarray9)

console.log("Original array splice:", array9);
// Out:
// Spliced: [ 20, 30, 40 ]
// Original array splice: [ 10, 50 ]

// %%
let array10 = [10,20,30,40,50]

let splicedarray10 = array10.splice(1,2)

console.log("Spliced:",splicedarray10)

console.log("Original array splice:", array10);
// Out:
// Spliced: [ 20, 30 ]
// Original array splice: [ 10, 40, 50 ]

// %%
let array11 = ["ram","shyam","kumar","raju","yeshwanth","dileep"]

let splicedarray11 = array11.splice(1,1)

console.log("Spliced:",splicedarray11)

console.log("Original array splice:", array11);
// Out:
// Spliced: [ 'shyam' ]
// Original array splice: [ 'ram', 'kumar', 'raju', 'yeshwanth', 'dileep' ]

// %%
let array12 = ["ram","shyam","kumar","raju","yeshwanth","dileep"]

let splicedarray12 = array12.splice(1,2)

console.log("Spliced:",splicedarray12)

console.log("Original array splice:", array12);
// Out:
// Spliced: [ 'shyam', 'kumar' ]
// Original array splice: [ 'ram', 'raju', 'yeshwanth', 'dileep' ]

// %%
let array13 = ["ram","shyam","kumar","raju","yeshwanth","dileep"]

let splicedarray13 = array13.splice(1,2)

console.log("Spliced:",splicedarray13)

console.log("Original array splice:", array13);
// Out:
// Spliced: [ 'shyam', 'kumar' ]
// Original array splice: [ 'ram', 'raju', 'yeshwanth', 'dileep' ]

// %%
let array14 = ["ram","shyam","kumar","raju","yeshwanth","dileep"]

let splicedarray14 = array14.splice(1,3)

console.log("Spliced:",splicedarray14)

console.log("Original array splice:", array14);
// Out:
// Spliced: [ 'shyam', 'kumar', 'raju' ]
// Original array splice: [ 'ram', 'yeshwanth', 'dileep' ]

// %%
let vegetables = ["tomato","potato","beans","cailiflower","betroot","brinjal"]

let insertvegetables = vegetables.splice(2,0,"x")

console.log("Spliced:",insertvegetables)

console.log("Original array splice:", vegetables);
// Out:
// Spliced: []
// Original array splice: [
//   'tomato',
//   'potato',
//   'x',
//   'beans',
//   'cailiflower',
//   'betroot',
//   'brinjal'
// ]

// %%
let animals = ["dog","cat","tiger"]


let splicedanimals = animals.splice(1,1,"lion")

console.log("Spliced:",splicedanimals);

console.log("Original array splice:", animals);
// Out:
// Spliced: [ 'cat' ]
// Original array splice: [ 'dog', 'lion', 'tiger' ]

// %%
let chemicals = ["zinc","phosphorus","magnesium","aluminium","nitogen","hydrogen"]

let splicedchemicals = chemicals.splice(4)

console.log("Spliced:",splicedchemicals);

console.log("Original array splice:", chemicals);
// Out:
// Spliced: [ 'nitogen', 'hydrogen' ]
// Original array splice: [ 'zinc', 'phosphorus', 'magnesium', 'aluminium' ]

// %%
let chemicals2 = ["zinc","phosphorus","magnesium","aluminium","nitogen","hydrogen"]

let splicedchemicals2 = chemicals2.splice(4,5)

console.log("Spliced:",splicedchemicals2);

console.log("Original array splice:", chemicals2);
// Out:
// Spliced: [ 'nitogen', 'hydrogen' ]
// Original array splice: [ 'zinc', 'phosphorus', 'magnesium', 'aluminium' ]

// %% [markdown]
// Remove duplicate manually
//
// Without Set.
//
// Use:
//
// includes
// push

// %%
let array15 = [1,2,2,3,4,4]
resultarr = []


for (let i = 0; i < array15.length; i++){

        if (!resultarr.includes(array15[i])) {
             resultarr.push(array15[i])
        }
}
console.log(resultarr)
// Out:
// [ 1, 2, 3, 4 ]

// %%
numbers = [1,2,3,4,5,6]

even_res = []

for (let i = 0;i < numbers.length ;i++){
    if (numbers[i] % 2  == 0){
        even_res.push(numbers[i])
    }
}

console.log(even_res)
// Out:
// [ 2, 4, 6 ]

// %%
numbers2 = [-1, 2, -5, 7, -9]

count = 0

for (let i =0; i < numbers2.length; i++){
    if (numbers2[i] < 0){

        count++
        
    }    
}

console.log(count)
// Out:
// 3

// %%
numbers3 = [10, 99, 45,2001, 2, 100,2000]

larg = numbers3[0]

for (let i = 1; i < numbers3.length; i++){
    if (numbers3[i] > larg){
        larg = numbers3[i]
    }
}

console.log(larg)
// Out:
// 2001
